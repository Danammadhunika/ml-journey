# %%
import numpy as np

# %%
ages = np.array([22, 38, 26, 35, 28, 0, 54, 2, 27, 14])

# %%
ages.shape
# Out:
# (10,)

# %%
ages[0]
# Out:
# np.int64(22)

# %%
ages[2:5]
# Out:
# array([26, 35, 28])

# %%
ages.mean()
# Out:
# np.float64(24.6)

# %%
print(ages.mean())
# Out:
# 24.6

# %%
print(ages[2])
# Out:
# 26

# %%
print(ages[4:8])
# Out:
# [28  0 54  2]

# %%
ages_2d = np.array([[22, 38, 26, 35, 28],
                    [0, 54, 2, 27, 14]])

# %%
print(ages_2d)
# Out:
# [[22 38 26 35 28]
#  [ 0 54  2 27 14]]

# %%
ages_2d.shape
# Out:
# (2, 5)

# %%
print(ages_2d[0])
print(ages_2d[1])
# Out:
# [22 38 26 35 28]
# [ 0 54  2 27 14]

# %%
print(ages_2d[0][1])
print(ages_2d[1][1])
# Out:
# 38
# 54

# %%
ages_2d.mean()
# Out:
# np.float64(24.6)

# %%
print(ages_2d.max())
print(ages_2d.min())
# Out:
# 54
# 0
